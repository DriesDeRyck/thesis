# %%
import pandas as pd
from conda.core.initialize import run_plan_from_temp_file

# %%
microbes_df = pd.read_csv("../examples/soils/microbes.from_biom.tsv", sep='\t', index_col=0).drop(columns="9hr_late")

# %%
microbes_df.head()
# Out:
#                          3min_early  3min_earlymid  3min_latemid  3min_late  \
# #OTU ID
# rplo 1 (Cyanobacteria)       4121.0         4489.0        2032.0     5313.0
# rplo 2 (Firmicutes)             0.0           25.0           0.0        0.0
# rplo 60 (Firmicutes)            0.0            0.0           0.0        0.0
# rplo 7 (Actinobacteria)       196.0          122.0         171.0      337.0
# rplo 10 (Firmicutes)            0.0            0.0           0.0        0.0
#
#                          9hr_early  9hr_earlymid  9hr_latemid  18hr_early  \
# #OTU ID
# rplo 1 (Cyanobacteria)      2077.0        1551.0       2157.0      3771.0
# rplo 2 (Firmicutes)         3832.0        3523.0       4843.0      2592.0
# rplo 60 (Firmicutes)           0.0           0.0          0.0         0.0
# rplo 7 (Actinobacteria)      488.0         345.0        326.0       457.0
# rplo 10 (Firmicutes)           0.0           0.0          0.0       775.0
#
# ...

# %%
# select first row from dataframe
row = microbes_df.iloc[0:2]
# print(row.name)
# new_df = pd.DataFrame(data=row).T
# new_df
row
# Out:
#                         3min_early  3min_earlymid  3min_latemid  3min_late  \
# #OTU ID
# rplo 1 (Cyanobacteria)      4121.0         4489.0        2032.0     5313.0
# rplo 2 (Firmicutes)            0.0           25.0           0.0        0.0
#
#                         9hr_early  9hr_earlymid  9hr_latemid  18hr_early  \
# #OTU ID
# rplo 1 (Cyanobacteria)     2077.0        1551.0       2157.0      3771.0
# rplo 2 (Firmicutes)        3832.0        3523.0       4843.0      2592.0
#
#                         18hr_earlymid  18hr_latemid  18hr_late  42hr_early  \
# #OTU ID
# rplo 1 (Cyanobacteria)         1016.0        1538.0      976.0      2117.0
# rplo 2 (Firmicutes)              19.0        6867.0        0.0      1781.0
#
#                         42hr_earlymid  42hr_latemid  42hr_late  49p5hr_early  \
# #OTU ID
# rplo 1 (Cyanobacteria)         1417.0         113.0      765.0         301.0
# rplo 2 (Firmicutes)            2435.0        1641.0      152.0         195.0
#
# ...

# %%
row.to_csv("./rplo-1-(Cyanobacteria).tsv", sep='\t')

# %%
# !biom convert -i rplo-1-\(Cyanobacteria\).tsv -o rplo-1-\(Cyanobacteria\).from_tsv.biom --table-type="OTU table" --to-hdf5

# %%
# !biom head -i rplo-1-\(Cyanobacteria\).from_tsv.biom -n 2 -m 10
# Out:
# # Constructed from biom file
# #OTU ID	3min_early	3min_earlymid	3min_latemid	3min_late	9hr_early	9hr_earlymid	9hr_latemid	18hr_early	18hr_earlymid	18hr_latemid
# rplo 1 (Cyanobacteria)	4121.0	4489.0	2032.0	5313.0	2077.0	1551.0	2157.0	3771.0	1016.0	1538.0
# rplo 2 (Firmicutes)	0.0	25.0	0.0	0.0	3832.0	3523.0	4843.0	2592.0	19.0	6867.0

# %%
# !biom head -i ../examples/soils/metabolites.biom -n 10 -m 10
# Out:
# # Constructed from biom file
# #OTU ID	3min_early	9hr_early	18hr_early	42hr_early	49p5hr_early	3min_earlymid	9hr_earlymid	18hr_earlymid	42hr_earlymid	49p5hr_earlymid
# (2,3-dihydroxy-3-methylbutanoate)	1.0	68.12459106	18559.00781	9310.292615	57205.32463	460.9148926	98720.52243	70304.58097	57261.97904	167448.2324
# (2,5-diaminohexanoate)	2782242.25	1217995.294	2818005.938	3086052.5	5842490.313	1883228.25	1757143.45	2765782.953	2649203.5	3627547.8
# (3-hydroxypyridine)	2764132.25	5701840.3	8118056.25	5199015.75	17578552.5	3014543.813	6778304.6	17206076.13	23994691.5	13553115.1
# (3-methyladenine)	3151923.688	36544924.8	31575138.25	9924625.375	4164767.563	4224009.313	54461337.6	59127978.0	23158721.33	36506855.4
# (4-oxoproline)	145094920.0	144491739.2	31982087.0	7295747.0	4504692.375	150345346.5	287291443.2	163220696.0	12458802.92	13284054.95
# (5,6-dihydrothymine)	10668504.06	11836450.8	13566340.88	9029176.0	4497692.5	9343810.875	22711707.8	31458363.0	8567759.0	10543409.9
# ...

# %%
# !python3 ../scripts/mmvec paired-omics \
    --microbe-file rplo-1-\(Cyanobacteria\).from_tsv.biom \
    --metabolite-file metabolites.biom \
    --summary-dir two-microbes-summary \
    --latent-dim 1
# Out:
# /home/dries/anaconda3/envs/mmvec_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/dries/anaconda3/envs/mmvec_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/dries/anaconda3/envs/mmvec_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
