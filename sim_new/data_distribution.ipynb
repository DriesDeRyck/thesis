# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
microbes = pd.read_csv('./data/microbes.tsv', sep='\t', index_col=0)
metabolites = pd.read_csv('./data/metabolites.tsv', sep='\t', index_col=0)

# %%
print(f"min: {microbes.values.min()}, median: {np.median(microbes.values.ravel())}, max: {microbes.values.max()}, mean: {microbes.values.mean()}")
# print(np.sort(microbes.values.ravel())[-60:])
print(f"num_zero = {len(microbes.values.ravel()[microbes.values.ravel() == 0])} / {len(microbes.values.ravel())}")
# Out:
# min: 0.0, median: 4.0, max: 2660.0, mean: 12.665684523809524
# num_zero = 67766 / 504000

# %%
print(f"min: {metabolites.values.min()}, median: {np.median(metabolites.values.ravel())}, max: {metabolites.values.max()}, mean: {metabolites.values.mean()}")
# print(np.sort(metabolites.values.ravel())[-60:])
print(f"num_zero = {len(metabolites.values.ravel()[metabolites.values.ravel() == 0])} / {len(metabolites.values.ravel())}")
# Out:
# min: 0.0, median: 219347.9255698279, max: 365507582.86258775, mean: 1445554.2055835456
# num_zero = 37800 / 882000

# %%
plt.hist(microbes.values.ravel()[microbes.values.ravel() > 100], bins=20)
# Out:
# (array([6.758e+03, 1.166e+03, 4.390e+02, 1.370e+02, 6.600e+01, 2.100e+01,
#         2.900e+01, 2.100e+01, 8.000e+00, 9.000e+00, 6.000e+00, 0.000e+00,
#         4.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00,
#         0.000e+00, 2.000e+00]),
#  array([ 101.  ,  228.95,  356.9 ,  484.85,  612.8 ,  740.75,  868.7 ,
#          996.65, 1124.6 , 1252.55, 1380.5 , 1508.45, 1636.4 , 1764.35,
#         1892.3 , 2020.25, 2148.2 , 2276.15, 2404.1 , 2532.05, 2660.  ]),
#  <BarContainer object of 20 artists>)

# %%
clr_microbes = pd.read_csv('./data/clr_microbes.tsv', sep='\t', index_col=0)
clr_metabolites = pd.read_csv('./data/clr_metabolites.tsv', sep='\t', index_col=0)
clr_microbes
# Out:
#                sample_378  sample_379  sample_380  sample_381  sample_382  \
# OTU_ID
# theta_p_0      223.401789  226.002136  224.180248  218.219586  231.417374
# theta_p_1      221.523520  225.239996  223.936187  217.492916  232.190564
# theta_p_2      222.771106  225.896775  224.503900  215.500486  228.709324
# theta_p_3      220.100412  223.699551  223.656602  216.541940  231.107219
# theta_p_4      219.301904  225.239996  222.679351  215.654637  232.391934
# ...                   ...         ...         ...         ...         ...
# noise_otu_195  218.714118  222.600938  219.817150  215.095021  228.016177
# noise_otu_196  219.937893  226.002136  220.222615  213.708727  228.016177
# noise_otu_197  219.301904  223.987233  222.068441  214.807339  230.095618
# noise_otu_198  218.714118 -521.839133  220.222615  214.807339  228.016177
# noise_otu_199  217.104680  225.165888 -525.316069  216.599098 -517.117042
#
# ...

# %%
plt.hist(clr_metabolites.values.ravel(), bins=20)
# Out:
# (array([3.78000e+04, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 3.13000e+02, 7.01749e+05,
#         8.66950e+04, 5.04300e+03, 0.00000e+00, 0.00000e+00, 5.04000e+04]),
#  array([-535.52378701, -496.13820543, -456.75262384, -417.36704226,
#         -377.98146067, -338.59587909, -299.21029751, -259.82471592,
#         -220.43913434, -181.05355275, -141.66797117, -102.28238959,
#          -62.896808  ,  -23.51122642,   15.87435517,   55.25993675,
#           94.64551833,  134.03109992,  173.4166815 ,  212.80226309,
#          252.18784467]),
#  <BarContainer object of 20 artists>)
