# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from random import sample
import random
random.seed(4131)

# %%
microbes = pd.read_csv('./data/microbes.tsv', sep='\t', index_col=0)
metabolites = pd.read_csv('./data/metabolites.tsv', sep='\t', index_col=0)
microbes.head()
# Out:
#            sample_378  sample_379  sample_380  sample_381  sample_382  \
# OTU_ID
# theta_p_0       543.0        30.0       157.0        91.0        60.0
# theta_p_1        83.0        14.0       123.0        44.0       130.0
# theta_p_2       289.0        27.0       217.0         6.0         4.0
# theta_p_3        20.0         3.0        93.0        17.0        44.0
# theta_p_4         9.0        14.0        35.0         7.0       159.0
#
#            sample_383  sample_384  sample_385  sample_386  sample_387  ...  \
# OTU_ID                                                                 ...
# theta_p_0       145.0       153.0        90.0        38.0      1171.0  ...
# theta_p_1        19.0        41.0       114.0        40.0        38.0  ...
# theta_p_2         8.0       232.0        47.0         9.0        15.0  ...
# theta_p_3        36.0        27.0        13.0        82.0        42.0  ...
# theta_p_4       168.0        40.0        23.0        56.0        26.0  ...
#
# ...

# %%
sample(list(microbes.columns), 10)
# Out:
# ['sample_432',
#  'sample_588',
#  'sample_1505',
#  'sample_521',
#  'sample_2170',
#  'sample_1432',
#  'sample_1634',
#  'sample_1284',
#  'sample_2365',
#  'sample_514']

# %%
subset20 = microbes[sample(list(microbes.columns), 20)]
subset100 = microbes[sample(list(microbes.columns), 100)]
subset500 = microbes[sample(list(microbes.columns), 500)]

# %%
subset20.head()
# Out:
#            sample_1034  sample_2085  sample_619  sample_133  sample_1063  \
# #OTU ID
# theta_p_0        113.0        246.0        83.0       109.0         15.0
# theta_p_1         37.0         65.0       301.0        66.0         30.0
# theta_p_2         52.0         32.0        30.0        36.0         75.0
# theta_p_3         27.0        153.0        86.0        15.0        198.0
# theta_p_4         62.0         72.0        86.0        20.0         26.0
#
#            sample_1980  sample_1039  sample_1464  sample_1470  sample_215  \
# #OTU ID
# theta_p_0        140.0        604.0         35.0         80.0       123.0
# theta_p_1        141.0        134.0         76.0         44.0        58.0
# theta_p_2        147.0         14.0          4.0        111.0        97.0
# theta_p_3        131.0        121.0         72.0         46.0        12.0
# theta_p_4         98.0         28.0         30.0         66.0        13.0
#
# ...

# %%
for i in [20, 100, 500]:
    columns_subset = sample(list(microbes.columns), i)
    microbes_subset = microbes[columns_subset]
    metabolites_subset = metabolites[columns_subset]
    microbes_subset.to_csv(f'./data/microbes.subset{str(i)}.tsv', sep='\t', index=True)
    metabolites_subset.to_csv(f'./data/metabolites.subset{str(i)}.tsv', sep='\t', index=True)
